# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
folder_path = './recaptcha-dataset/Large'
class_D = {}
files_and_folders = os.listdir(folder_path)

# 해당 경로의 모든 파일 및 폴더 이름 리스트 반환
files_and_folders = os.listdir(folder_path)

# 폴더 이름만 필터링하여 리스트에 저장
folder_names = [f for f in files_and_folders if os.path.isdir(os.path.join(folder_path, f))]
folder_dic = {}
print(folder_names)
for a in folder_names:
    folder_dic[a] = os.listdir(folder_path+"/"+a)
    print(a, len(folder_dic[a]))
# Out:
# ['Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney', 'Crosswalk', 'Hydrant', 'Motorcycle', 'Palm', 'Traffic Light']
# Bicycle 468
# Bridge 765
# Bus 1170
# Car 453
# Chimney 198
# Crosswalk 462
# Hydrant 714
# Motorcycle 156
# Palm 339
# Traffic Light 288

# %%
def norm_hist(hist):
   #정규화 => 이미지 크기에 상관없이 히스토그램 그려줘 - 모든 값 0-1 매핑핑
    # Normalize the histogram
    hist = hist.astype('float')
    hist /= hist.sum()
    return hist


def hist_gram(image):
    hist_b, bins_b = np.histogram(image[0], bins=128, range=(0, 256)) #bin 만큼의 차원의 feature 뽑을 수 있다.
    hist_g, bins_g = np.histogram(image[1], bins=128, range=(0, 256))
    hist_r, bins_r = np.histogram(image[2], bins=128, range=(0, 256))
    hist_b = norm_hist(hist_b)    # 256-d
    hist_g = norm_hist(hist_g)    # 256-d
    hist_r = norm_hist(hist_r)    # 256-d
    # gray histogram 입력을 grat -> bin을 128 -> 사실은 띄워져 있다.
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    hist_gray, bins_gray = np.histogram(gray, bins=128, range=(0, 256))
    hist_gray = norm_hist(hist_gray)    # 128-d

    return hist_b, hist_g, hist_r, hist_gray

# %%
# Law's texture
from scipy import signal as sg

def laws_texture(gray):
    (rows, cols) = gray.shape[:2] #행과 열의 개수 - 크기기
    
    #gray scale에 대해 smoothing한 이미지를 원본에서 빼준다. 5*5짜리의 mean 필터를 적용해줬다.
    smooth_kernel = (1/25)*np.ones((5,5))
    gray_smooth = sg.convolve(gray, smooth_kernel,"same")
    gray_processed = np.abs(gray - gray_smooth)
    

    filter_vectors = np.array([[ 1,  4,  6,  4, 1],    # L5
                               [-1, -2,  0,  2, 1],    # E5
                               [-1,  0,  2,  0, 1],    # S5
                               [ 1, -4,  6, -4, 1]])   # R5

    # 0:L5L5, 1:L5E5, 2:L5S5, 3:L5R5, 
    # 4:E5L5, 5:E5E5, 6:E5S5, 7:E5R5,
    # 8:S5L5, 9:S5E5, 10:S5S5, 11:S5R5, 
    # 12:R5L5, 13:R5E5, 14:R5S5, 15:R5R5
    filters = list()
    for i in range(4):
        for j in range(4):
            filters.append(np.matmul(filter_vectors[i][:].reshape(5,1),
                                     filter_vectors[j][:].reshape(1,5)))

    conv_maps = np.zeros((rows, cols,16))
    for i in range(len(filters)):
        conv_maps[:, :, i] = sg.convolve(gray_processed,
                                         filters[i],'same')
    #16개의 값 중 가장 중요한 9개 선정
    texture_maps = list()
    texture_maps.append((conv_maps[:, :, 1]+conv_maps[:, :, 4])//2)     # L5E5 / E5L5
    texture_maps.append((conv_maps[:, :, 2]+conv_maps[:, :, 8])//2)     # L5S5 / S5L5
    texture_maps.append((conv_maps[:, :, 3]+conv_maps[:, :, 12])//2)    # L5R5 / R5L5
    texture_maps.append((conv_maps[:, :, 7]+conv_maps[:, :, 13])//2)    # E5R5 / R5E5
    texture_maps.append((conv_maps[:, :, 6]+conv_maps[:, :, 9])//2)     # E5S5 / S5E5 
    texture_maps.append((conv_maps[:, :, 11]+conv_maps[:, :, 14])//2)   # S5R5 / R5S5
    texture_maps.append(conv_maps[:, :, 10])                            # S5S5
    texture_maps.append(conv_maps[:, :, 5])                             # E5E5
    texture_maps.append(conv_maps[:, :, 15])                            # R5R5
    texture_maps.append(conv_maps[:, :, 0])                             # L5L5 (use to norm TEM)하나의 feature 값으로 저장하길 원하기에 normalization => 9개의 숫자가 나온다.
#숫자 9개로 나오게 하려고고


    TEM = list()
    for i in range(9):
        TEM.append(np.abs(texture_maps[i]).sum() / np.abs(texture_maps[9]).sum())
        
    return TEM

# laws = laws_texture(gray)    # 9-d laws_texture 직접 함수로 구현하기! - 특징 벡터 제일 많이 쓸겨!
# print(laws)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
recaptcha = './recaptcha-dataset/Large'
query_path = './query'
# labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 
#           'Crosswalk', 'Motorcycle']
labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney', 
           'Crosswalk', 'Hydrant', 'Motorcycle', 'Palm', 'Traffic Light']

sbt_train_features = []
sbt_train_labels = []
q_sbt_test_features = []

for label in labels:
    image_dir = os.path.join(recaptcha, label)
    image_list = os.listdir(image_dir)
    for i, image_name in enumerate(image_list):

        image_path = os.path.join(image_dir, image_name)
        img = cv2.imread(image_path)

        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
 
        if i < 150:
            sbt_train_features.append(laws_texture(gray_img))
            sbt_train_labels.append(label)
        else:
            break

query_list = os.listdir(query_path)
for i, q_name in enumerate(query_list):
        
        q_path = os.path.join(query_path, q_name)
        image = cv2.resize(cv2.imread(q_path),(120,120))
        
        gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
 
        if i < 100:
            q_sbt_test_features.append(laws_texture(gray_img))
        else:
            break

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from skimage.feature import local_binary_pattern

recaptcha = './recaptcha-dataset/Large'
# labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 
#           'Crosswalk', 'Motorcycle']
labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney', 
           'Crosswalk', 'Hydrant', 'Motorcycle', 'Palm', 'Traffic Light']

lbp_train_features = []
lbp_train_labels = []
q_lbp_test_features = []

for label in labels:
    image_dir = os.path.join(recaptcha, label)
    image_list = os.listdir(image_dir)
    for i, image_name in enumerate(image_list):

        image_path = os.path.join(image_dir, image_name)
        img = cv2.imread(image_path)

        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        lbp = local_binary_pattern(gray_img, P=8, R=1) #R=1 -> 바로 인접 8개의 픽셀값 고려하겠다. 더 멀리 보려면 R을 늘려려

        hist_lbp, bin_lbp = np.histogram(lbp.ravel(), bins=64, range=(0, 256)) #256차원을 bin값으로 축소할수도!
        hist_lbp = norm_hist(hist_lbp)    # 64-d


        if i < 150:
            lbp_train_features.append(hist_lbp)
            lbp_train_labels.append(label)

        else:
            break

query_list = os.listdir(query_path)
for i, q_name in enumerate(query_list):
        
        q_path = os.path.join(query_path, q_name)
        image = cv2.resize(cv2.imread(q_path),(120,120))
        gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        lbp = local_binary_pattern(gray_img, P=8, R=1) #R=1 -> 바로 인접 8개의 픽셀값 고려하겠다. 더 멀리 보려면 R을 늘려려

        hist_lbp, bin_lbp = np.histogram(lbp.ravel(), bins=64, range=(0, 256)) #256차원을 bin값으로 축소할수도!
        hist_lbp = norm_hist(hist_lbp)    # 64-d

        if i < 100:
            q_lbp_test_features.append(hist_lbp)
        else:
            break

# %%
lst = []
for i in range(len(sbt_train_features)):
    npa = np.array(sbt_train_features[i])
    lst.append(npa)
final_train_features = np.concatenate([lbp_train_features, lst], axis = 1)
Lst = []
for i in range(len(q_sbt_test_features)):
    npa = np.array(q_sbt_test_features[i])
    Lst.append(npa)
final_test_features = np.concatenate([q_lbp_test_features, Lst], axis = 1)

final_classifier = KNeighborsClassifier(n_neighbors = 5)

final_classifier.fit(final_train_features, lbp_train_labels)
final_predict_labels = final_classifier.predict(final_test_features)
print(final_predict_labels)
print(query_list)
# Out:
# ['Bus' 'Palm' 'Hydrant' 'Hydrant' 'Chimney' 'Bridge' 'Bus' 'Chimney'
#  'Motorcycle' 'Bus' 'Palm' 'Bicycle' 'Crosswalk' 'Car' 'Crosswalk'
#  'Hydrant' 'Bicycle' 'Chimney' 'Hydrant' 'Bicycle' 'Palm' 'Car' 'Bicycle'
#  'Crosswalk' 'Palm' 'Crosswalk' 'Chimney' 'Chimney' 'Chimney' 'Bus' 'Palm'
#  'Bicycle' 'Bridge' 'Bicycle' 'Bicycle' 'Bicycle' 'Car' 'Chimney'
#  'Chimney' 'Traffic Light' 'Bicycle' 'Chimney' 'Chimney' 'Bicycle' 'Bus'
#  'Hydrant' 'Bicycle' 'Bridge' 'Bicycle' 'Hydrant' 'Bridge' 'Palm' 'Palm'
#  'Bridge' 'Hydrant' 'Bicycle' 'Car' 'Traffic Light' 'Bicycle' 'Bus' 'Palm'
#  'Crosswalk' 'Crosswalk' 'Bus' 'Crosswalk' 'Hydrant' 'Palm' 'Bus'
#  'Bicycle' 'Crosswalk' 'Hydrant' 'Hydrant' 'Motorcycle' 'Car' 'Bridge'
#  'Crosswalk' 'Bicycle' 'Hydrant' 'Bicycle' 'Bicycle' 'Hydrant' 'Car'
#  'Crosswalk' 'Chimney' 'Bridge' 'Bicycle' 'Chimney' 'Hydrant' 'Bus'
#  'Chimney' 'Crosswalk' 'Bicycle' 'Palm' 'Chimney' 'Bicycle' 'Bicycle'
#  'Chimney' 'Palm' 'Hydrant' 'Bicycle']
# ['query1.png', 'query10.png', 'query100.png', 'query11.png', 'query12.png', 'query13.png', 'query14.png', 'query15.png', 'query16.png', 'query17.png', 'query18.png', 'query19.png', 'query2.png', 'query20.png', 'query21.png', 'query22.png', 'query23.png', 'query24.png', 'query25.png', 'query26.png', 'query27.png', 'query28.png', 'query29.png', 'query3.png', 'query30.png', 'query31.png', 'query32.png', 'query33.png', 'query34.png', 'query35.png', 'query36.png', 'query37.png', 'query38.png', 'query39.png', 'query4.png', 'query40.png', 'query41.png', 'query42.png', 'query43.png', 'query44.png', 'query45.png', 'query46.png', 'query47.png', 'query48.png', 'query49.png', 'query5.png', 'query50.png', 'query51.png', 'query52.png', 'query53.png', 'query54.png', 'query55.png', 'query56.png', 'query57.png', 'query58.png', 'query59.png', 'query6.png', 'query60.png', 'query61.png', 'query62.png', 'query63.png', 'query64.png', 'query65.png', 'query66.png', 'query67.png', 'query68.png', 'query69.png', 'query7.png', 'query70.png', 'query71.png', 'query72.png', 'query73.png', 'query74.png', 'query75.png', 'query76.png', 'query77.png', 'query78.png', 'query79.png', 'query8.png', 'query80.png', 'query81.png', 'query82.png', 'query83.png', 'query84.png', 'query85.png', 'query86.png', 'query87.png', 'query88.png', 'query89.png', 'query9.png', 'query90.png', 'query91.png', 'query92.png', 'query93.png', 'query94.png', 'query95.png', 'query96.png', 'query97.png', 'query98.png', 'query99.png']

# %%
neigh_ind = final_classifier.kneighbors(final_test_features, n_neighbors=10, return_distance=False) # Top-10 results
neigh_labels = np.array(lbp_train_labels)[neigh_ind]

# %%
print(neigh_labels)
# Out:
# [['Hydrant' 'Hydrant' 'Palm' 'Bus' 'Bus' 'Bridge' 'Bus' 'Bridge'
#   'Hydrant' 'Bus']
#  ['Palm' 'Motorcycle' 'Traffic Light' 'Palm' 'Palm' 'Palm' 'Palm' 'Palm'
#   'Palm' 'Palm']
#  ['Bicycle' 'Hydrant' 'Car' 'Hydrant' 'Bus' 'Bus' 'Bicycle' 'Car'
#   'Bridge' 'Hydrant']
#  ['Hydrant' 'Chimney' 'Palm' 'Palm' 'Hydrant' 'Bicycle' 'Hydrant'
#   'Bicycle' 'Hydrant' 'Chimney']
#  ['Chimney' 'Chimney' 'Palm' 'Chimney' 'Chimney' 'Chimney' 'Chimney'
#   'Chimney' 'Palm' 'Chimney']
#  ['Bridge' 'Car' 'Bridge' 'Car' 'Crosswalk' 'Crosswalk' 'Crosswalk'
#   'Bridge' 'Bicycle' 'Hydrant']
#  ['Bus' 'Bus' 'Car' 'Traffic Light' 'Bicycle' 'Bus' 'Car' 'Bus' 'Bus'
#   'Bus']
#  ['Palm' 'Traffic Light' 'Chimney' 'Chimney' 'Chimney' 'Palm' 'Crosswalk'
#   'Palm' 'Palm' 'Palm']
#  ['Motorcycle' 'Car' 'Bicycle' 'Motorcycle' 'Motorcycle' 'Bicycle'
#   'Crosswalk' 'Motorcycle' 'Bicycle' 'Car']
#  ['Bus' 'Bus' 'Bridge' 'Bus' 'Bus' 'Bus' 'Bus' 'Bridge' 'Bus' 'Bridge']
#  ['Palm' 'Palm' 'Traffic Light' 'Palm' 'Crosswalk' 'Palm' 'Palm'
#   'Chimney' 'Traffic Light' 'Palm']
#  ['Car' 'Palm' 'Bicycle' 'Bridge' 'Crosswalk' 'Motorcycle' 'Chimney'
#   'Car' 'Chimney' 'Bicycle']
#  ['Crosswalk' 'Hydrant' 'Crosswalk' 'Chimney' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Bicycle' 'Crosswalk']
#  ['Car' 'Bus' 'Car' 'Car' 'Bicycle' 'Car' 'Bridge' 'Crosswalk' 'Bus'
#   'Bicycle']
#  ['Bus' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Bicycle'
#   'Crosswalk' 'Bicycle' 'Crosswalk' 'Bridge']
#  ['Bus' 'Hydrant' 'Hydrant' 'Hydrant' 'Hydrant' 'Hydrant' 'Hydrant'
#   'Palm' 'Car' 'Bicycle']
#  ['Bicycle' 'Bicycle' 'Bicycle' 'Bridge' 'Motorcycle' 'Crosswalk'
#   'Hydrant' 'Palm' 'Crosswalk' 'Chimney']
#  ['Chimney' 'Palm' 'Chimney' 'Chimney' 'Chimney' 'Palm' 'Chimney' 'Palm'
#   'Chimney' 'Traffic Light']
#  ['Hydrant' 'Car' 'Hydrant' 'Hydrant' 'Hydrant' 'Bicycle' 'Hydrant'
#   'Hydrant' 'Chimney' 'Bicycle']
#  ['Bus' 'Bicycle' 'Hydrant' 'Car' 'Bicycle' 'Crosswalk' 'Bicycle'
#   'Hydrant' 'Crosswalk' 'Hydrant']
#  ['Palm' 'Bridge' 'Palm' 'Palm' 'Chimney' 'Palm' 'Palm' 'Bridge'
#   'Bicycle' 'Hydrant']
#  ['Hydrant' 'Car' 'Car' 'Car' 'Crosswalk' 'Bus' 'Motorcycle' 'Bridge'
#   'Palm' 'Crosswalk']
#  ['Bicycle' 'Bicycle' 'Hydrant' 'Bicycle' 'Bridge' 'Bridge' 'Hydrant'
#   'Hydrant' 'Bus' 'Chimney']
#  ['Crosswalk' 'Bridge' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Car' 'Car'
#   'Motorcycle' 'Bridge' 'Bridge']
#  ['Chimney' 'Palm' 'Palm' 'Bicycle' 'Car' 'Chimney' 'Bicycle' 'Palm'
#   'Motorcycle' 'Bridge']
#  ['Crosswalk' 'Bus' 'Crosswalk' 'Hydrant' 'Hydrant' 'Bicycle' 'Hydrant'
#   'Bicycle' 'Chimney' 'Hydrant']
#  ['Palm' 'Chimney' 'Bus' 'Palm' 'Chimney' 'Crosswalk' 'Palm' 'Palm'
#   'Palm' 'Chimney']
#  ['Chimney' 'Chimney' 'Hydrant' 'Chimney' 'Chimney' 'Palm' 'Bridge'
#   'Hydrant' 'Palm' 'Chimney']
#  ['Chimney' 'Crosswalk' 'Chimney' 'Chimney' 'Palm' 'Palm' 'Hydrant' 'Bus'
#   'Chimney' 'Bicycle']
#  ['Bicycle' 'Bus' 'Motorcycle' 'Bus' 'Car' 'Motorcycle' 'Car'
#   'Motorcycle' 'Bus' 'Crosswalk']
#  ['Chimney' 'Palm' 'Palm' 'Traffic Light' 'Palm' 'Motorcycle' 'Bridge'
#   'Palm' 'Traffic Light' 'Motorcycle']
#  ['Palm' 'Chimney' 'Bicycle' 'Motorcycle' 'Car' 'Traffic Light' 'Bridge'
#   'Chimney' 'Hydrant' 'Bus']
#  ['Bridge' 'Crosswalk' 'Bridge' 'Car' 'Bridge' 'Crosswalk' 'Palm' 'Palm'
#   'Palm' 'Bridge']
#  ['Bridge' 'Bus' 'Bicycle' 'Chimney' 'Palm' 'Chimney' 'Bus' 'Chimney'
#   'Crosswalk' 'Traffic Light']
#  ['Hydrant' 'Bicycle' 'Hydrant' 'Bicycle' 'Car' 'Car' 'Hydrant'
#   'Crosswalk' 'Hydrant' 'Motorcycle']
#  ['Car' 'Bicycle' 'Bridge' 'Car' 'Bicycle' 'Crosswalk' 'Car' 'Car' 'Car'
#   'Car']
#  ['Car' 'Crosswalk' 'Car' 'Car' 'Hydrant' 'Motorcycle' 'Motorcycle'
#   'Traffic Light' 'Bicycle' 'Hydrant']
#  ['Chimney' 'Chimney' 'Chimney' 'Chimney' 'Chimney' 'Chimney' 'Chimney'
#   'Chimney' 'Crosswalk' 'Chimney']
#  ['Chimney' 'Chimney' 'Chimney' 'Chimney' 'Bicycle' 'Chimney' 'Chimney'
#   'Palm' 'Palm' 'Palm']
#  ['Traffic Light' 'Chimney' 'Traffic Light' 'Motorcycle' 'Palm' 'Palm'
#   'Palm' 'Palm' 'Palm' 'Traffic Light']
#  ['Bicycle' 'Bicycle' 'Bus' 'Crosswalk' 'Bicycle' 'Bicycle' 'Bicycle'
#   'Hydrant' 'Crosswalk' 'Bicycle']
#  ['Chimney' 'Chimney' 'Palm' 'Traffic Light' 'Palm' 'Chimney' 'Palm'
#   'Palm' 'Chimney' 'Chimney']
#  ['Chimney' 'Chimney' 'Chimney' 'Chimney' 'Chimney' 'Hydrant' 'Hydrant'
#   'Chimney' 'Chimney' 'Bicycle']
#  ['Bicycle' 'Hydrant' 'Bicycle' 'Bicycle' 'Bus' 'Bicycle' 'Motorcycle'
#   'Bus' 'Hydrant' 'Motorcycle']
#  ['Bus' 'Chimney' 'Hydrant' 'Bus' 'Bus' 'Crosswalk' 'Bus' 'Car' 'Car'
#   'Bridge']
#  ['Hydrant' 'Car' 'Hydrant' 'Traffic Light' 'Hydrant' 'Bicycle'
#   'Motorcycle' 'Motorcycle' 'Motorcycle' 'Bus']
#  ['Bicycle' 'Hydrant' 'Bicycle' 'Bicycle' 'Bus' 'Crosswalk' 'Hydrant'
#   'Car' 'Hydrant' 'Hydrant']
#  ['Crosswalk' 'Hydrant' 'Bicycle' 'Bridge' 'Bridge' 'Hydrant' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Bicycle']
#  ['Hydrant' 'Palm' 'Bus' 'Bicycle' 'Traffic Light' 'Bus' 'Bus' 'Bus'
#   'Crosswalk' 'Bus']
#  ['Bus' 'Hydrant' 'Hydrant' 'Bicycle' 'Hydrant' 'Hydrant' 'Bicycle'
#   'Hydrant' 'Hydrant' 'Hydrant']
#  ['Bridge' 'Bridge' 'Chimney' 'Crosswalk' 'Car' 'Palm' 'Crosswalk'
#   'Crosswalk' 'Motorcycle' 'Car']
#  ['Palm' 'Motorcycle' 'Palm' 'Bicycle' 'Hydrant' 'Car' 'Crosswalk'
#   'Bicycle' 'Bicycle' 'Traffic Light']
#  ['Palm' 'Bus' 'Crosswalk' 'Palm' 'Chimney' 'Bicycle' 'Palm' 'Chimney'
#   'Chimney' 'Bus']
#  ['Bus' 'Crosswalk' 'Car' 'Bridge' 'Hydrant' 'Bus' 'Hydrant' 'Bridge'
#   'Bridge' 'Bus']
#  ['Hydrant' 'Hydrant' 'Bicycle' 'Hydrant' 'Bicycle' 'Bicycle' 'Hydrant'
#   'Hydrant' 'Hydrant' 'Crosswalk']
#  ['Bicycle' 'Bridge' 'Car' 'Bicycle' 'Crosswalk' 'Car' 'Bridge' 'Bridge'
#   'Crosswalk' 'Bus']
#  ['Hydrant' 'Car' 'Bicycle' 'Hydrant' 'Car' 'Hydrant' 'Bicycle' 'Palm'
#   'Motorcycle' 'Motorcycle']
#  ['Traffic Light' 'Traffic Light' 'Traffic Light' 'Traffic Light'
#   'Traffic Light' 'Chimney' 'Motorcycle' 'Palm' 'Motorcycle' 'Palm']
#  ['Bicycle' 'Bicycle' 'Bus' 'Bicycle' 'Crosswalk' 'Bus' 'Hydrant' 'Car'
#   'Bus' 'Car']
#  ['Bicycle' 'Bus' 'Bus' 'Bus' 'Motorcycle' 'Hydrant' 'Car' 'Bus' 'Bus'
#   'Bus']
#  ['Bicycle' 'Palm' 'Chimney' 'Palm' 'Palm' 'Palm' 'Hydrant' 'Bus'
#   'Chimney' 'Motorcycle']
#  ['Crosswalk' 'Motorcycle' 'Chimney' 'Crosswalk' 'Car' 'Bicycle'
#   'Hydrant' 'Motorcycle' 'Crosswalk' 'Crosswalk']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Chimney' 'Bicycle' 'Chimney'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Palm']
#  ['Bus' 'Bus' 'Bus' 'Bicycle' 'Bus' 'Hydrant' 'Bus' 'Hydrant' 'Hydrant'
#   'Car']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Bridge' 'Crosswalk' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Bridge' 'Crosswalk']
#  ['Bridge' 'Hydrant' 'Hydrant' 'Bicycle' 'Crosswalk' 'Palm' 'Crosswalk'
#   'Hydrant' 'Chimney' 'Car']
#  ['Palm' 'Palm' 'Palm' 'Palm' 'Palm' 'Palm' 'Palm' 'Palm' 'Chimney'
#   'Palm']
#  ['Bus' 'Bus' 'Bus' 'Motorcycle' 'Bus' 'Bus' 'Palm' 'Hydrant' 'Bus'
#   'Motorcycle']
#  ['Hydrant' 'Bicycle' 'Motorcycle' 'Bicycle' 'Bicycle' 'Bridge' 'Bicycle'
#   'Bicycle' 'Hydrant' 'Motorcycle']
#  ['Bus' 'Chimney' 'Crosswalk' 'Crosswalk' 'Traffic Light' 'Chimney'
#   'Crosswalk' 'Palm' 'Bicycle' 'Bicycle']
#  ['Hydrant' 'Hydrant' 'Bicycle' 'Bus' 'Hydrant' 'Bicycle' 'Bicycle'
#   'Hydrant' 'Bicycle' 'Bicycle']
#  ['Hydrant' 'Hydrant' 'Motorcycle' 'Chimney' 'Hydrant' 'Hydrant'
#   'Hydrant' 'Car' 'Hydrant' 'Hydrant']
#  ['Car' 'Hydrant' 'Motorcycle' 'Motorcycle' 'Motorcycle' 'Bus' 'Hydrant'
#   'Car' 'Car' 'Motorcycle']
#  ['Car' 'Bicycle' 'Car' 'Hydrant' 'Crosswalk' 'Car' 'Bus' 'Car' 'Car'
#   'Car']
#  ['Bus' 'Chimney' 'Bridge' 'Palm' 'Crosswalk' 'Hydrant' 'Bus' 'Chimney'
#   'Bicycle' 'Chimney']
#  ['Bus' 'Bicycle' 'Crosswalk' 'Hydrant' 'Crosswalk' 'Bicycle' 'Hydrant'
#   'Bridge' 'Crosswalk' 'Crosswalk']
#  ['Bridge' 'Bicycle' 'Bicycle' 'Crosswalk' 'Car' 'Car' 'Bus' 'Crosswalk'
#   'Car' 'Car']
#  ['Hydrant' 'Hydrant' 'Hydrant' 'Bicycle' 'Car' 'Hydrant' 'Bicycle'
#   'Crosswalk' 'Bicycle' 'Car']
#  ['Crosswalk' 'Motorcycle' 'Bicycle' 'Bus' 'Bicycle' 'Bicycle' 'Car'
#   'Crosswalk' 'Bicycle' 'Motorcycle']
#  ['Crosswalk' 'Car' 'Bicycle' 'Bicycle' 'Bus' 'Crosswalk' 'Car'
#   'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Motorcycle' 'Hydrant' 'Hydrant' 'Hydrant' 'Hydrant' 'Bicycle'
#   'Crosswalk' 'Hydrant' 'Hydrant' 'Motorcycle']
#  ['Car' 'Bicycle' 'Car' 'Hydrant' 'Hydrant' 'Hydrant' 'Bus' 'Bus' 'Bus'
#   'Hydrant']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Bicycle' 'Hydrant'
#   'Bridge' 'Bicycle' 'Crosswalk' 'Crosswalk']
#  ['Chimney' 'Chimney' 'Palm' 'Palm' 'Chimney' 'Chimney' 'Palm' 'Palm'
#   'Palm' 'Chimney']
#  ['Chimney' 'Bridge' 'Bridge' 'Bus' 'Chimney' 'Bicycle' 'Bicycle' 'Car'
#   'Car' 'Crosswalk']
#  ['Bridge' 'Hydrant' 'Bus' 'Bicycle' 'Bicycle' 'Hydrant' 'Bicycle'
#   'Bicycle' 'Traffic Light' 'Car']
#  ['Chimney' 'Chimney' 'Palm' 'Palm' 'Hydrant' 'Crosswalk' 'Chimney'
#   'Crosswalk' 'Chimney' 'Bicycle']
#  ['Bicycle' 'Hydrant' 'Bicycle' 'Hydrant' 'Hydrant' 'Hydrant' 'Hydrant'
#   'Hydrant' 'Bicycle' 'Hydrant']
#  ['Motorcycle' 'Bus' 'Bus' 'Traffic Light' 'Bus' 'Hydrant' 'Bus'
#   'Traffic Light' 'Bus' 'Bicycle']
#  ['Bus' 'Chimney' 'Chimney' 'Palm' 'Palm' 'Chimney' 'Bicycle' 'Bus'
#   'Chimney' 'Chimney']
#  ['Crosswalk' 'Crosswalk' 'Bicycle' 'Motorcycle' 'Hydrant' 'Hydrant'
#   'Crosswalk' 'Hydrant' 'Bicycle' 'Bicycle']
#  ['Bicycle' 'Bicycle' 'Hydrant' 'Bicycle' 'Crosswalk' 'Crosswalk'
#   'Bicycle' 'Hydrant' 'Hydrant' 'Hydrant']
#  ['Palm' 'Palm' 'Hydrant' 'Bicycle' 'Palm' 'Bicycle' 'Bicycle' 'Hydrant'
#   'Hydrant' 'Hydrant']
#  ['Chimney' 'Traffic Light' 'Traffic Light' 'Chimney' 'Palm' 'Palm'
#   'Palm' 'Palm' 'Palm' 'Chimney']
#  ['Bus' 'Motorcycle' 'Bicycle' 'Car' 'Traffic Light' 'Car' 'Car' 'Car'
#   'Car' 'Bus']
#  ['Bicycle' 'Palm' 'Traffic Light' 'Bicycle' 'Chimney' 'Bicycle'
#   'Crosswalk' 'Motorcycle' 'Palm' 'Motorcycle']
#  ['Chimney' 'Palm' 'Palm' 'Bridge' 'Chimney' 'Palm' 'Palm' 'Palm' 'Palm'
#   'Palm']
#  ['Bus' 'Bicycle' 'Palm' 'Palm' 'Chimney' 'Palm' 'Palm' 'Chimney' 'Bus'
#   'Traffic Light']
#  ['Hydrant' 'Hydrant' 'Car' 'Hydrant' 'Car' 'Hydrant' 'Bus' 'Car'
#   'Hydrant' 'Hydrant']
#  ['Bicycle' 'Hydrant' 'Traffic Light' 'Crosswalk' 'Palm' 'Hydrant'
#   'Hydrant' 'Hydrant' 'Hydrant' 'Hydrant']]

# %%
import csv

with open('c1_t2_a2.csv','w') as file :
    write = csv.writer(file)
    for i in range(len(final_predict_labels)):
        write.writerow([query_list[i]] + list(neigh_labels[i]))
