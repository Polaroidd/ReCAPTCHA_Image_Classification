# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
folder_path = './recaptcha-dataset/QC'
class_D = {}
files_and_folders = os.listdir(folder_path)

# 해당 경로의 모든 파일 및 폴더 이름 리스트 반환
files_and_folders = os.listdir(folder_path)

# 폴더 이름만 필터링하여 리스트에 저장
folder_names = [f for f in files_and_folders if os.path.isdir(os.path.join(folder_path, f))]
folder_dic = {}
print(folder_names)
for a in folder_names:
    folder_dic[a] = os.listdir(folder_path+"/"+a)
    print(a, len(folder_dic[a]))
# Out:
# ['Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney', 'Crosswalk', 'Hydrant', 'Motorcycle', 'Palm', 'Traffic Light']
# Bicycle 28
# Bridge 19
# Bus 17
# Car 21
# Chimney 20
# Crosswalk 20
# Hydrant 20
# Motorcycle 21
# Palm 19
# Traffic Light 24

# %%
def norm_hist(hist):
   #정규화 => 이미지 크기에 상관없이 히스토그램 그려줘 - 모든 값 0-1 매핑핑
    # Normalize the histogram
    hist = hist.astype('float')
    hist /= hist.sum()
    return hist


def hist_gram(image):
    hist_b, bins_b = np.histogram(image[0], bins=128, range=(0, 256)) #bin 만큼의 차원의 feature 뽑을 수 있다.
    hist_g, bins_g = np.histogram(image[1], bins=128, range=(0, 256))
    hist_r, bins_r = np.histogram(image[2], bins=128, range=(0, 256))
    hist_b = norm_hist(hist_b)    # 256-d
    hist_g = norm_hist(hist_g)    # 256-d
    hist_r = norm_hist(hist_r)    # 256-d
    # gray histogram 입력을 grat -> bin을 128 -> 사실은 띄워져 있다.
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    hist_gray, bins_gray = np.histogram(gray, bins=128, range=(0, 256))
    hist_gray = norm_hist(hist_gray)    # 128-d

    return hist_b, hist_g, hist_r, hist_gray

# %%
# Law's texture
from scipy import signal as sg

def laws_texture(gray):
    (rows, cols) = gray.shape[:2] #행과 열의 개수 - 크기기
    
    #gray scale에 대해 smoothing한 이미지를 원본에서 빼준다. 5*5짜리의 mean 필터를 적용해줬다.
    smooth_kernel = (1/25)*np.ones((5,5))
    gray_smooth = sg.convolve(gray, smooth_kernel,"same")
    gray_processed = np.abs(gray - gray_smooth)
    

    filter_vectors = np.array([[ 1,  4,  6,  4, 1],    # L5
                               [-1, -2,  0,  2, 1],    # E5
                               [-1,  0,  2,  0, 1],    # S5
                               [ 1, -4,  6, -4, 1]])   # R5

    # 0:L5L5, 1:L5E5, 2:L5S5, 3:L5R5, 
    # 4:E5L5, 5:E5E5, 6:E5S5, 7:E5R5,
    # 8:S5L5, 9:S5E5, 10:S5S5, 11:S5R5, 
    # 12:R5L5, 13:R5E5, 14:R5S5, 15:R5R5
    filters = list()
    for i in range(4):
        for j in range(4):
            filters.append(np.matmul(filter_vectors[i][:].reshape(5,1),
                                     filter_vectors[j][:].reshape(1,5)))

    conv_maps = np.zeros((rows, cols,16))
    for i in range(len(filters)):
        conv_maps[:, :, i] = sg.convolve(gray_processed,
                                         filters[i],'same')
    #16개의 값 중 가장 중요한 9개 선정
    texture_maps = list()
    texture_maps.append((conv_maps[:, :, 1]+conv_maps[:, :, 4])//2)     # L5E5 / E5L5
    texture_maps.append((conv_maps[:, :, 2]+conv_maps[:, :, 8])//2)     # L5S5 / S5L5
    texture_maps.append((conv_maps[:, :, 3]+conv_maps[:, :, 12])//2)    # L5R5 / R5L5
    texture_maps.append((conv_maps[:, :, 7]+conv_maps[:, :, 13])//2)    # E5R5 / R5E5
    texture_maps.append((conv_maps[:, :, 6]+conv_maps[:, :, 9])//2)     # E5S5 / S5E5 
    texture_maps.append((conv_maps[:, :, 11]+conv_maps[:, :, 14])//2)   # S5R5 / R5S5
    texture_maps.append(conv_maps[:, :, 10])                            # S5S5
    texture_maps.append(conv_maps[:, :, 5])                             # E5E5
    texture_maps.append(conv_maps[:, :, 15])                            # R5R5
    texture_maps.append(conv_maps[:, :, 0])                             # L5L5 (use to norm TEM)하나의 feature 값으로 저장하길 원하기에 normalization => 9개의 숫자가 나온다.
#숫자 9개로 나오게 하려고고


    TEM = list()
    for i in range(9):
        TEM.append(np.abs(texture_maps[i]).sum() / np.abs(texture_maps[9]).sum())
        
    return TEM

# laws = laws_texture(gray)    # 9-d laws_texture 직접 함수로 구현하기! - 특징 벡터 제일 많이 쓸겨!
# print(laws)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
recaptcha = './recaptcha-dataset/QC'
query_path = './query'
# labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 
#           'Crosswalk', 'Motorcycle']
labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney', 
           'Crosswalk', 'Hydrant', 'Motorcycle', 'Palm', 'Traffic Light']

sbt_train_features = []
sbt_train_labels = []
q_sbt_test_features = []

for label in labels:
    image_dir = os.path.join(recaptcha, label)
    image_list = os.listdir(image_dir)
    for i, image_name in enumerate(image_list):

        image_path = os.path.join(image_dir, image_name)
        img = cv2.imread(image_path)

        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        sbt_train_features.append(laws_texture(gray_img))
        sbt_train_labels.append(label)
        

query_list = os.listdir(query_path)
for i, q_name in enumerate(query_list):
        
        q_path = os.path.join(query_path, q_name)
        image = cv2.resize(cv2.imread(q_path),(120,120))
        
        gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
 
        if i < 100:
            q_sbt_test_features.append(laws_texture(gray_img))
        else:
            break

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from skimage.feature import local_binary_pattern

recaptcha = './recaptcha-dataset/QC'
# labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 
#           'Crosswalk', 'Motorcycle']
labels = ['Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney', 
           'Crosswalk', 'Hydrant', 'Motorcycle', 'Palm', 'Traffic Light']

lbp_train_features = []
lbp_train_labels = []
q_lbp_test_features = []

for label in labels:
    image_dir = os.path.join(recaptcha, label)
    image_list = os.listdir(image_dir)
    for i, image_name in enumerate(image_list):

        image_path = os.path.join(image_dir, image_name)
        img = cv2.imread(image_path)

        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        lbp = local_binary_pattern(gray_img, P=8, R=1) #R=1 -> 바로 인접 8개의 픽셀값 고려하겠다. 더 멀리 보려면 R을 늘려려

        hist_lbp, bin_lbp = np.histogram(lbp.ravel(), bins=64, range=(0, 256)) #256차원을 bin값으로 축소할수도!
        hist_lbp = norm_hist(hist_lbp)    # 64-d
        lbp_train_features.append(hist_lbp)
        lbp_train_labels.append(label)

query_list = os.listdir(query_path)
for i, q_name in enumerate(query_list):
        
        q_path = os.path.join(query_path, q_name)
        image = cv2.resize(cv2.imread(q_path),(120,120))
        gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        lbp = local_binary_pattern(gray_img, P=8, R=1) #R=1 -> 바로 인접 8개의 픽셀값 고려하겠다. 더 멀리 보려면 R을 늘려려

        hist_lbp, bin_lbp = np.histogram(lbp.ravel(), bins=64, range=(0, 256)) #256차원을 bin값으로 축소할수도!
        hist_lbp = norm_hist(hist_lbp)    # 64-d

        if i < 100:
            q_lbp_test_features.append(hist_lbp)
        else:
            break

# %%
lst = []
for i in range(len(sbt_train_features)):
    npa = np.array(sbt_train_features[i])
    lst.append(npa)
final_train_features = np.concatenate([lbp_train_features, lst], axis = 1)
Lst = []
for i in range(len(q_sbt_test_features)):
    npa = np.array(q_sbt_test_features[i])
    Lst.append(npa)
final_test_features = np.concatenate([q_lbp_test_features, Lst], axis = 1)

final_classifier = KNeighborsClassifier(n_neighbors = 5)

final_classifier.fit(final_train_features, lbp_train_labels)
final_predict_labels = final_classifier.predict(final_test_features)
print(final_predict_labels)
print(query_list)
# Out:
# ['Bus' 'Palm' 'Bus' 'Motorcycle' 'Chimney' 'Traffic Light' 'Motorcycle'
#  'Crosswalk' 'Crosswalk' 'Bridge' 'Traffic Light' 'Palm' 'Bridge' 'Bus'
#  'Crosswalk' 'Motorcycle' 'Bridge' 'Palm' 'Chimney' 'Hydrant' 'Palm' 'Bus'
#  'Bridge' 'Crosswalk' 'Bicycle' 'Bridge' 'Crosswalk' 'Chimney' 'Chimney'
#  'Car' 'Palm' 'Bicycle' 'Palm' 'Chimney' 'Motorcycle' 'Crosswalk'
#  'Motorcycle' 'Chimney' 'Chimney' 'Palm' 'Car' 'Palm' 'Chimney' 'Bus'
#  'Bus' 'Traffic Light' 'Hydrant' 'Crosswalk' 'Bus' 'Hydrant' 'Palm'
#  'Bicycle' 'Bicycle' 'Chimney' 'Hydrant' 'Crosswalk' 'Traffic Light'
#  'Motorcycle' 'Hydrant' 'Bridge' 'Hydrant' 'Crosswalk' 'Bridge' 'Car'
#  'Bridge' 'Bicycle' 'Chimney' 'Bus' 'Hydrant' 'Crosswalk' 'Bridge' 'Bus'
#  'Hydrant' 'Bus' 'Chimney' 'Bridge' 'Car' 'Bicycle' 'Hydrant' 'Car'
#  'Hydrant' 'Bicycle' 'Bridge' 'Palm' 'Bridge' 'Chimney' 'Crosswalk'
#  'Bridge' 'Bus' 'Chimney' 'Hydrant' 'Hydrant' 'Hydrant' 'Palm'
#  'Motorcycle' 'Hydrant' 'Palm' 'Bus' 'Motorcycle' 'Chimney']
# ['query1.png', 'query10.png', 'query100.png', 'query11.png', 'query12.png', 'query13.png', 'query14.png', 'query15.png', 'query16.png', 'query17.png', 'query18.png', 'query19.png', 'query2.png', 'query20.png', 'query21.png', 'query22.png', 'query23.png', 'query24.png', 'query25.png', 'query26.png', 'query27.png', 'query28.png', 'query29.png', 'query3.png', 'query30.png', 'query31.png', 'query32.png', 'query33.png', 'query34.png', 'query35.png', 'query36.png', 'query37.png', 'query38.png', 'query39.png', 'query4.png', 'query40.png', 'query41.png', 'query42.png', 'query43.png', 'query44.png', 'query45.png', 'query46.png', 'query47.png', 'query48.png', 'query49.png', 'query5.png', 'query50.png', 'query51.png', 'query52.png', 'query53.png', 'query54.png', 'query55.png', 'query56.png', 'query57.png', 'query58.png', 'query59.png', 'query6.png', 'query60.png', 'query61.png', 'query62.png', 'query63.png', 'query64.png', 'query65.png', 'query66.png', 'query67.png', 'query68.png', 'query69.png', 'query7.png', 'query70.png', 'query71.png', 'query72.png', 'query73.png', 'query74.png', 'query75.png', 'query76.png', 'query77.png', 'query78.png', 'query79.png', 'query8.png', 'query80.png', 'query81.png', 'query82.png', 'query83.png', 'query84.png', 'query85.png', 'query86.png', 'query87.png', 'query88.png', 'query89.png', 'query9.png', 'query90.png', 'query91.png', 'query92.png', 'query93.png', 'query94.png', 'query95.png', 'query96.png', 'query97.png', 'query98.png', 'query99.png']

# %%
neigh_ind = final_classifier.kneighbors(X = final_test_features, n_neighbors=10, return_distance=False) # Top-10 results
neigh_labels = np.array(lbp_train_labels)[neigh_ind]

# %%
print(neigh_labels)
# Out:
# [['Hydrant' 'Bus' 'Chimney' 'Hydrant' 'Bus' 'Hydrant' 'Car' 'Motorcycle'
#   'Bus' 'Bridge']
#  ['Chimney' 'Traffic Light' 'Traffic Light' 'Palm' 'Palm' 'Palm'
#   'Motorcycle' 'Chimney' 'Chimney' 'Bridge']
#  ['Bus' 'Bus' 'Bicycle' 'Bus' 'Hydrant' 'Car' 'Bus' 'Car' 'Bus'
#   'Motorcycle']
#  ['Palm' 'Motorcycle' 'Chimney' 'Hydrant' 'Motorcycle' 'Traffic Light'
#   'Motorcycle' 'Hydrant' 'Hydrant' 'Traffic Light']
#  ['Palm' 'Bus' 'Chimney' 'Chimney' 'Crosswalk' 'Hydrant' 'Traffic Light'
#   'Traffic Light' 'Bridge' 'Bicycle']
#  ['Traffic Light' 'Bridge' 'Crosswalk' 'Traffic Light' 'Bicycle'
#   'Crosswalk' 'Crosswalk' 'Chimney' 'Crosswalk' 'Bridge']
#  ['Car' 'Motorcycle' 'Motorcycle' 'Bicycle' 'Bus' 'Bicycle' 'Bus' 'Bus'
#   'Traffic Light' 'Car']
#  ['Crosswalk' 'Palm' 'Traffic Light' 'Crosswalk' 'Chimney' 'Crosswalk'
#   'Traffic Light' 'Chimney' 'Chimney' 'Palm']
#  ['Bicycle' 'Crosswalk' 'Car' 'Bus' 'Crosswalk' 'Motorcycle' 'Crosswalk'
#   'Crosswalk' 'Motorcycle' 'Chimney']
#  ['Car' 'Bridge' 'Motorcycle' 'Chimney' 'Bus' 'Bus' 'Bus' 'Hydrant'
#   'Chimney' 'Bus']
#  ['Crosswalk' 'Palm' 'Traffic Light' 'Traffic Light' 'Chimney' 'Palm'
#   'Chimney' 'Traffic Light' 'Crosswalk' 'Chimney']
#  ['Palm' 'Bus' 'Car' 'Chimney' 'Palm' 'Bus' 'Bicycle' 'Traffic Light'
#   'Crosswalk' 'Car']
#  ['Bridge' 'Bridge' 'Hydrant' 'Hydrant' 'Chimney' 'Bridge' 'Bridge'
#   'Bridge' 'Car' 'Motorcycle']
#  ['Bicycle' 'Chimney' 'Hydrant' 'Bus' 'Bus' 'Car' 'Hydrant' 'Motorcycle'
#   'Motorcycle' 'Bicycle']
#  ['Hydrant' 'Chimney' 'Car' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Bridge'
#   'Car' 'Hydrant' 'Car']
#  ['Traffic Light' 'Car' 'Hydrant' 'Motorcycle' 'Motorcycle' 'Hydrant'
#   'Crosswalk' 'Traffic Light' 'Bicycle' 'Hydrant']
#  ['Bus' 'Motorcycle' 'Hydrant' 'Bridge' 'Car' 'Bridge' 'Bridge' 'Bus'
#   'Bicycle' 'Bridge']
#  ['Crosswalk' 'Palm' 'Palm' 'Traffic Light' 'Traffic Light' 'Palm'
#   'Chimney' 'Crosswalk' 'Traffic Light' 'Traffic Light']
#  ['Crosswalk' 'Chimney' 'Hydrant' 'Motorcycle' 'Traffic Light' 'Bus'
#   'Hydrant' 'Bicycle' 'Chimney' 'Bicycle']
#  ['Hydrant' 'Motorcycle' 'Bicycle' 'Hydrant' 'Bus' 'Hydrant' 'Chimney'
#   'Motorcycle' 'Hydrant' 'Car']
#  ['Bus' 'Chimney' 'Palm' 'Palm' 'Car' 'Bicycle' 'Motorcycle' 'Bus'
#   'Bridge' 'Bicycle']
#  ['Car' 'Bus' 'Bus' 'Bus' 'Bicycle' 'Bridge' 'Motorcycle' 'Hydrant'
#   'Motorcycle' 'Bus']
#  ['Bridge' 'Bridge' 'Bridge' 'Hydrant' 'Chimney' 'Chimney' 'Chimney'
#   'Motorcycle' 'Hydrant' 'Bus']
#  ['Crosswalk' 'Crosswalk' 'Hydrant' 'Hydrant' 'Crosswalk' 'Motorcycle'
#   'Crosswalk' 'Car' 'Bicycle' 'Bicycle']
#  ['Chimney' 'Palm' 'Car' 'Motorcycle' 'Bicycle' 'Bridge' 'Palm' 'Bicycle'
#   'Traffic Light' 'Bicycle']
#  ['Bridge' 'Bridge' 'Bridge' 'Chimney' 'Chimney' 'Traffic Light'
#   'Hydrant' 'Traffic Light' 'Chimney' 'Bridge']
#  ['Palm' 'Crosswalk' 'Crosswalk' 'Traffic Light' 'Traffic Light'
#   'Chimney' 'Crosswalk' 'Crosswalk' 'Traffic Light' 'Hydrant']
#  ['Bus' 'Chimney' 'Chimney' 'Chimney' 'Chimney' 'Bus' 'Traffic Light'
#   'Hydrant' 'Chimney' 'Bridge']
#  ['Chimney' 'Bus' 'Chimney' 'Traffic Light' 'Hydrant' 'Motorcycle'
#   'Bicycle' 'Crosswalk' 'Crosswalk' 'Bicycle']
#  ['Car' 'Hydrant' 'Hydrant' 'Motorcycle' 'Car' 'Crosswalk' 'Hydrant'
#   'Crosswalk' 'Car' 'Car']
#  ['Hydrant' 'Palm' 'Motorcycle' 'Palm' 'Palm' 'Palm' 'Traffic Light'
#   'Bridge' 'Palm' 'Chimney']
#  ['Bicycle' 'Chimney' 'Hydrant' 'Motorcycle' 'Bicycle' 'Bicycle'
#   'Chimney' 'Traffic Light' 'Hydrant' 'Bicycle']
#  ['Bus' 'Palm' 'Palm' 'Bridge' 'Chimney' 'Palm' 'Bicycle' 'Palm'
#   'Chimney' 'Traffic Light']
#  ['Chimney' 'Chimney' 'Chimney' 'Palm' 'Car' 'Bus' 'Traffic Light'
#   'Traffic Light' 'Crosswalk' 'Palm']
#  ['Hydrant' 'Motorcycle' 'Bus' 'Bicycle' 'Motorcycle' 'Hydrant' 'Chimney'
#   'Motorcycle' 'Hydrant' 'Bridge']
#  ['Motorcycle' 'Crosswalk' 'Car' 'Crosswalk' 'Bicycle' 'Crosswalk' 'Bus'
#   'Car' 'Car' 'Bridge']
#  ['Motorcycle' 'Hydrant' 'Motorcycle' 'Bus' 'Motorcycle' 'Crosswalk'
#   'Bicycle' 'Chimney' 'Hydrant' 'Car']
#  ['Crosswalk' 'Chimney' 'Chimney' 'Traffic Light' 'Palm' 'Bus' 'Bridge'
#   'Crosswalk' 'Chimney' 'Chimney']
#  ['Traffic Light' 'Chimney' 'Palm' 'Crosswalk' 'Chimney' 'Bus' 'Chimney'
#   'Bridge' 'Hydrant' 'Traffic Light']
#  ['Traffic Light' 'Palm' 'Palm' 'Car' 'Bicycle' 'Bus' 'Traffic Light'
#   'Palm' 'Bicycle' 'Bus']
#  ['Hydrant' 'Hydrant' 'Crosswalk' 'Car' 'Car' 'Motorcycle' 'Motorcycle'
#   'Hydrant' 'Bicycle' 'Crosswalk']
#  ['Palm' 'Palm' 'Crosswalk' 'Traffic Light' 'Traffic Light' 'Palm'
#   'Chimney' 'Traffic Light' 'Traffic Light' 'Palm']
#  ['Chimney' 'Chimney' 'Chimney' 'Traffic Light' 'Chimney' 'Bus' 'Bus'
#   'Chimney' 'Bridge' 'Chimney']
#  ['Car' 'Bus' 'Hydrant' 'Bridge' 'Bus' 'Motorcycle' 'Hydrant' 'Bridge'
#   'Bridge' 'Bus']
#  ['Bus' 'Chimney' 'Bus' 'Bus' 'Traffic Light' 'Car' 'Bridge' 'Bus' 'Car'
#   'Chimney']
#  ['Bicycle' 'Traffic Light' 'Traffic Light' 'Motorcycle' 'Hydrant' 'Car'
#   'Car' 'Palm' 'Hydrant' 'Motorcycle']
#  ['Hydrant' 'Hydrant' 'Chimney' 'Bicycle' 'Traffic Light' 'Chimney'
#   'Hydrant' 'Bridge' 'Bridge' 'Car']
#  ['Bridge' 'Bridge' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Bicycle'
#   'Hydrant' 'Car' 'Motorcycle' 'Hydrant']
#  ['Bus' 'Bridge' 'Bus' 'Car' 'Bicycle' 'Motorcycle' 'Bus' 'Car' 'Hydrant'
#   'Bridge']
#  ['Hydrant' 'Hydrant' 'Hydrant' 'Bus' 'Chimney' 'Bicycle' 'Motorcycle'
#   'Chimney' 'Car' 'Motorcycle']
#  ['Chimney' 'Bus' 'Palm' 'Palm' 'Bicycle' 'Car' 'Bus' 'Bus' 'Crosswalk'
#   'Car']
#  ['Palm' 'Bicycle' 'Traffic Light' 'Bicycle' 'Motorcycle' 'Car' 'Chimney'
#   'Bridge' 'Car' 'Car']
#  ['Bus' 'Chimney' 'Motorcycle' 'Bicycle' 'Palm' 'Chimney' 'Bicycle'
#   'Traffic Light' 'Car' 'Palm']
#  ['Chimney' 'Bus' 'Chimney' 'Chimney' 'Bridge' 'Car' 'Chimney' 'Bus'
#   'Bridge' 'Bus']
#  ['Hydrant' 'Hydrant' 'Car' 'Chimney' 'Bus' 'Bridge' 'Hydrant' 'Bridge'
#   'Chimney' 'Bus']
#  ['Crosswalk' 'Crosswalk' 'Crosswalk' 'Crosswalk' 'Bridge' 'Crosswalk'
#   'Crosswalk' 'Traffic Light' 'Hydrant' 'Traffic Light']
#  ['Bicycle' 'Traffic Light' 'Hydrant' 'Traffic Light' 'Motorcycle' 'Car'
#   'Hydrant' 'Motorcycle' 'Bicycle' 'Car']
#  ['Crosswalk' 'Motorcycle' 'Motorcycle' 'Motorcycle' 'Traffic Light'
#   'Motorcycle' 'Traffic Light' 'Palm' 'Hydrant' 'Chimney']
#  ['Hydrant' 'Car' 'Hydrant' 'Hydrant' 'Crosswalk' 'Motorcycle'
#   'Motorcycle' 'Car' 'Car' 'Bicycle']
#  ['Car' 'Bus' 'Bus' 'Bridge' 'Bridge' 'Hydrant' 'Motorcycle' 'Motorcycle'
#   'Bus' 'Chimney']
#  ['Hydrant' 'Traffic Light' 'Hydrant' 'Palm' 'Motorcycle' 'Traffic Light'
#   'Chimney' 'Chimney' 'Palm' 'Bridge']
#  ['Bridge' 'Crosswalk' 'Crosswalk' 'Bicycle' 'Crosswalk' 'Car' 'Hydrant'
#   'Car' 'Crosswalk' 'Bicycle']
#  ['Hydrant' 'Bridge' 'Bridge' 'Bus' 'Chimney' 'Hydrant' 'Bridge' 'Bridge'
#   'Bridge' 'Chimney']
#  ['Bicycle' 'Traffic Light' 'Car' 'Hydrant' 'Car' 'Bus' 'Motorcycle'
#   'Chimney' 'Motorcycle' 'Traffic Light']
#  ['Bridge' 'Bridge' 'Crosswalk' 'Crosswalk' 'Hydrant' 'Car' 'Crosswalk'
#   'Crosswalk' 'Crosswalk' 'Motorcycle']
#  ['Chimney' 'Bicycle' 'Bicycle' 'Car' 'Chimney' 'Hydrant' 'Chimney'
#   'Traffic Light' 'Motorcycle' 'Bicycle']
#  ['Traffic Light' 'Traffic Light' 'Palm' 'Chimney' 'Chimney'
#   'Traffic Light' 'Chimney' 'Traffic Light' 'Chimney' 'Crosswalk']
#  ['Car' 'Bus' 'Motorcycle' 'Bus' 'Bus' 'Car' 'Bus' 'Bus' 'Hydrant'
#   'Bicycle']
#  ['Hydrant' 'Hydrant' 'Bicycle' 'Bicycle' 'Hydrant' 'Crosswalk'
#   'Motorcycle' 'Car' 'Hydrant' 'Bicycle']
#  ['Crosswalk' 'Crosswalk' 'Chimney' 'Crosswalk' 'Car' 'Crosswalk'
#   'Hydrant' 'Bridge' 'Bridge' 'Hydrant']
#  ['Hydrant' 'Bridge' 'Bridge' 'Chimney' 'Bridge' 'Chimney' 'Hydrant'
#   'Hydrant' 'Chimney' 'Chimney']
#  ['Hydrant' 'Bicycle' 'Motorcycle' 'Bus' 'Bus' 'Bicycle' 'Motorcycle'
#   'Hydrant' 'Hydrant' 'Hydrant']
#  ['Bicycle' 'Hydrant' 'Motorcycle' 'Hydrant' 'Motorcycle' 'Motorcycle'
#   'Bicycle' 'Crosswalk' 'Motorcycle' 'Motorcycle']
#  ['Bus' 'Motorcycle' 'Bicycle' 'Hydrant' 'Bus' 'Chimney' 'Car' 'Bus'
#   'Car' 'Bridge']
#  ['Chimney' 'Chimney' 'Car' 'Palm' 'Chimney' 'Bus' 'Chimney'
#   'Traffic Light' 'Bridge' 'Bus']
#  ['Hydrant' 'Bridge' 'Bridge' 'Motorcycle' 'Crosswalk' 'Bicycle'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Hydrant']
#  ['Car' 'Car' 'Bicycle' 'Bridge' 'Crosswalk' 'Car' 'Motorcycle' 'Car'
#   'Bridge' 'Car']
#  ['Hydrant' 'Chimney' 'Motorcycle' 'Bus' 'Bicycle' 'Car' 'Motorcycle'
#   'Bridge' 'Motorcycle' 'Car']
#  ['Motorcycle' 'Hydrant' 'Bridge' 'Hydrant' 'Bicycle' 'Crosswalk' 'Car'
#   'Crosswalk' 'Crosswalk' 'Crosswalk']
#  ['Car' 'Car' 'Car' 'Crosswalk' 'Crosswalk' 'Car' 'Motorcycle' 'Car'
#   'Car' 'Crosswalk']
#  ['Hydrant' 'Hydrant' 'Chimney' 'Car' 'Bus' 'Hydrant' 'Bicycle' 'Bridge'
#   'Hydrant' 'Motorcycle']
#  ['Bicycle' 'Traffic Light' 'Hydrant' 'Crosswalk' 'Car' 'Traffic Light'
#   'Car' 'Hydrant' 'Bicycle' 'Bus']
#  ['Hydrant' 'Chimney' 'Bridge' 'Hydrant' 'Bridge' 'Crosswalk' 'Crosswalk'
#   'Car' 'Crosswalk' 'Car']
#  ['Crosswalk' 'Palm' 'Palm' 'Traffic Light' 'Palm' 'Traffic Light'
#   'Traffic Light' 'Chimney' 'Chimney' 'Chimney']
#  ['Bridge' 'Bridge' 'Crosswalk' 'Crosswalk' 'Traffic Light' 'Bicycle'
#   'Crosswalk' 'Crosswalk' 'Crosswalk' 'Hydrant']
#  ['Bicycle' 'Chimney' 'Hydrant' 'Hydrant' 'Chimney' 'Hydrant' 'Chimney'
#   'Traffic Light' 'Traffic Light' 'Bridge']
#  ['Bus' 'Bicycle' 'Crosswalk' 'Car' 'Crosswalk' 'Chimney' 'Hydrant'
#   'Motorcycle' 'Chimney' 'Hydrant']
#  ['Hydrant' 'Car' 'Bridge' 'Bridge' 'Bus' 'Hydrant' 'Bus' 'Bus' 'Bus'
#   'Bicycle']
#  ['Car' 'Bus' 'Bus' 'Bicycle' 'Hydrant' 'Bus' 'Bus' 'Bus' 'Car' 'Car']
#  ['Chimney' 'Traffic Light' 'Palm' 'Bus' 'Chimney' 'Traffic Light'
#   'Bridge' 'Crosswalk' 'Chimney' 'Car']
#  ['Crosswalk' 'Motorcycle' 'Hydrant' 'Hydrant' 'Bicycle' 'Chimney'
#   'Motorcycle' 'Bicycle' 'Motorcycle' 'Crosswalk']
#  ['Hydrant' 'Hydrant' 'Bridge' 'Bus' 'Car' 'Hydrant' 'Bus' 'Bridge'
#   'Bridge' 'Chimney']
#  ['Hydrant' 'Traffic Light' 'Hydrant' 'Chimney' 'Hydrant' 'Crosswalk'
#   'Bus' 'Hydrant' 'Car' 'Bicycle']
#  ['Palm' 'Bicycle' 'Palm' 'Palm' 'Traffic Light' 'Traffic Light'
#   'Crosswalk' 'Chimney' 'Traffic Light' 'Traffic Light']
#  ['Motorcycle' 'Hydrant' 'Bus' 'Crosswalk' 'Motorcycle' 'Car'
#   'Motorcycle' 'Car' 'Bus' 'Motorcycle']
#  ['Hydrant' 'Hydrant' 'Chimney' 'Bridge' 'Hydrant' 'Bridge'
#   'Traffic Light' 'Hydrant' 'Crosswalk' 'Bus']
#  ['Palm' 'Chimney' 'Palm' 'Palm' 'Traffic Light' 'Chimney' 'Chimney'
#   'Traffic Light' 'Traffic Light' 'Traffic Light']
#  ['Bus' 'Palm' 'Traffic Light' 'Hydrant' 'Chimney' 'Chimney'
#   'Traffic Light' 'Crosswalk' 'Chimney' 'Traffic Light']
#  ['Hydrant' 'Chimney' 'Motorcycle' 'Bus' 'Motorcycle' 'Car' 'Motorcycle'
#   'Motorcycle' 'Crosswalk' 'Car']
#  ['Hydrant' 'Chimney' 'Traffic Light' 'Chimney' 'Hydrant' 'Hydrant' 'Car'
#   'Motorcycle' 'Bicycle' 'Bus']]

# %%
import csv

with open('c1_t2_a1.csv','w') as file :
    write = csv.writer(file)
    for i in range(len(final_predict_labels)):
        write.writerow([query_list[i]] + list(neigh_labels[i]))
